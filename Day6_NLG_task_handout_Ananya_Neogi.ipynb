# %% [markdown]
# # Task: MLE and Policy Gradient trained sequence to sequence model in Texar
#
# We build two versions of a simple (but attention using) sequence-to-sequence model:
#
# - The first version will be trained only with an MLE objective,
# - The second will be trained both with MLE as a pretraining, and then Policy Gradient.
#
# The goal of the task is simply to get to know Texar a bit, nothing else -- the dataset is a toy dataset from Google which simply reverses the input, and without proper hyperparameter tuning (which we won't do) Policy Gradient quickly collapses, even after the MLE pretraining.
#
# Consequently, the task is simply to build the models and get the training running, there is no target performance which you'd have to achieve. In addition, almost all code that is needed can be found by looking at the Texar documentation...

# %% [markdown]
# # Texar prerequisites

# %%
! pip install texar
# Out:
# Requirement already satisfied: texar in /usr/local/lib/python3.6/dist-packages (0.2.4)
# Requirement already satisfied: regex>=2018.01.10 in /usr/local/lib/python3.6/dist-packages (from texar) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from texar) (2.21.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from texar) (20.3)
# Requirement already satisfied: pathlib>=1.0 in /usr/local/lib/python3.6/dist-packages (from texar) (1.0.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from texar) (3.13)
# Requirement already satisfied: numpy<1.17.0 in /usr/local/lib/python3.6/dist-packages (from texar) (1.16.6)
# Requirement already satisfied: funcsigs>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from texar) (1.0.2)
# Requirement already satisfied: sentencepiece>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from texar) (0.1.85)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->texar) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->texar) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->texar) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->texar) (2019.11.28)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->texar) (2.4.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->texar) (1.12.0)

# %%
import texar.tf as tx
import tensorflow as tf
import numpy as np
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will switch to TensorFlow 2.x on the 27th of March, 2020.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# %tensorflow_version
# Out:
# Currently selected TF version: 1.x
# Available versions:
# * 1.x
# * 2.x

# %% [markdown]
# # Downloading the data
# We download and extract the toy dataset with Texar's download utility function:

# %%
tx.data.maybe_download(
            urls='https://drive.google.com/file/d/'
                 '1fENE2rakm8vJ8d3voWBgW4hGlS6-KORW/view?usp=sharing',
            path='./',
            filenames='toy_copy.zip',
            extract=True)
# Out:
# ['./toy_copy.zip']

# %% [markdown]
# After extraction this will already be in the format needed for Texar's data readers.

# %% [markdown]
# # The basic model: RNN Seq2seq with attention trained with MLE

# %% [markdown]
# ## Model parameters
#
# In Texar, hyperparameters are typically represented by multi-level dictionaries (or  dictionary-like texar.HParams intstances). Before building the model, we define a minimal set of hyperparameter dictionaries for the embedding, encoder, decoder and attention.

# %%
# We want to use the same dimensionality ("number of units") for the embedding, and the encoder and decoder RNNs
num_units = 256 # Please, specify a reasonable number

# For inference, the model will use beam search
beam_width = 10 # Specify a reasonable number (remember that the search time is not 
                 # linear with respect to this parameter!)

embedder_hparams = {"dim": num_units}
encoder_hparams = {
    'rnn_cell_fw': {
        'kwargs': {
            'num_units': num_units
        }
    }
}
decoder_hparams = {
    'rnn_cell': {
        'kwargs': {
            'num_units': num_units
        },
    },
    'attention': {
        'kwargs': {
            'num_units': num_units,
        },
        'attention_layer_size': num_units
    }
}

# %% [markdown]
# ## Building the model
#
# First we build a simple seq2seq model with attention.

# %%
def build_mle_model(batch, train_data):
    """Build a basic seq2seq model with attention for MLE training.
    """
    
    # Please define a word embedding layer for the Encoder using Texar's API.
    # For hyperparameters, use the embedder hparams defined in the previous cell.
    source_embedder = tx.modules.WordEmbedder(
        vocab_size=train_data.source_vocab.size, hparams=embedder_hparams)
    
    # For encoder, use a Bidirectional RNN encoder from the Texar API.
    # hparams were defined above.
    encoder = tx.modules.BidirectionalRNNEncoder(hparams=encoder_hparams)

    enc_outputs, _ = encoder(source_embedder(batch['source_text_ids']))
    
    # Please define a word embedding layer for the Decoder using Texar's API.
    # For hyperparameters, use the embedder hparams defined in the previous cell.
    target_embedder = tx.modules.WordEmbedder(
        vocab_size=train_data.target_vocab.size, hparams=embedder_hparams)

    # The decoder should be a Texar Attention RNN decoder with the hyperparameters 
    # defined above
    decoder = tx.modules.AttentionRNNDecoder(
        memory=tf.concat(enc_outputs, axis=2),
        memory_sequence_length=batch['source_length'],
        vocab_size=train_data.target_vocab.size,
        hparams=decoder_hparams)

    # For MLE training, we use greedy decoding and teacher forcing, 
    # this is why the input is coming from the target text
    mle_training_outputs, _, _ = decoder(
        decoding_strategy='train_greedy', # Please specify greedy training decoding here 
                               # see the possible values in the Texar "Decoders" documentation section
        inputs=target_embedder(batch['target_text_ids'][:, :-1]),
        sequence_length=batch['target_length'] - 1)

    # The loss for MLE training is the familiar sparse softmax cross entropy
    # Please use the Texar version of it here!
    mle_loss = tx.losses.sequence_sparse_softmax_cross_entropy(
        labels=batch['target_text_ids'][:, 1:],
        logits=mle_training_outputs.logits,
        sequence_length=batch['target_length'] - 1)

    # Texar produces a train op from the loss for us:
    mle_train_op = tx.core.get_train_op(mle_loss)

    # For inference (text generation), we need the start (bos) tokens from the data set
    # and we produce here a whole vector of them, for the entire batch.
    start_tokens = tf.ones_like(batch['target_length']) * train_data.target_vocab.bos_token_id

    # Inference (text generation) by beam search -- nothing to do here, just observe!
    beam_search_outputs, _, _ = \
        tx.modules.beam_search_decode(
            decoder_or_cell=decoder,
            embedding=target_embedder,
            start_tokens=start_tokens,
            end_token=train_data.target_vocab.eos_token_id,
            beam_width=beam_width,
            max_decoding_length=60)

    # Having built the model, we need to return two things that will be needed for the training
    # and evaluation of the model: the mle training op  and the beam search output 
    # please add these in the next line (in this order)!!
    return mle_train_op, beam_search_outputs

# %% [markdown]
# ## Data sets and training parameters

# %%
source_vocab_file = './data/toy_copy/train/vocab.sources.txt'
target_vocab_file = './data/toy_copy/train/vocab.targets.txt'

mle_training_num_epochs  = 40 # Please specify the number of training epochs
steps_per_train_epochs = 312 # Don't touch this, this is the correct value for the toy dataset
batch_size = 50 # Please specify a batch size

display = 50

# Texar hparams for the toy dataset

train_hparams = {
    'num_epochs': 500, # We set this to an unexhaustible number bec. of a Texar bug!!
    'batch_size': batch_size,
    'allow_smaller_final_batch': False,
    'source_dataset': {
        "files": './data/toy_copy/train/sources.txt',
        'vocab_file': source_vocab_file
    },
    'target_dataset': {
        'files': './data/toy_copy/train/targets.txt',
        'vocab_file': target_vocab_file
    }
}
val_hparams = {
    'batch_size': batch_size,
    'allow_smaller_final_batch': False,
    'source_dataset': {
        "files": './data/toy_copy/dev/sources.txt',
        'vocab_file': source_vocab_file
    },
    'target_dataset': {
        "files": './data/toy_copy/dev/targets.txt',
        'vocab_file': target_vocab_file
    }
}
test_hparams = {
    'batch_size': batch_size,
    'allow_smaller_final_batch': False,
    'source_dataset': {
        "files": './data/toy_copy/test/sources.txt',
        'vocab_file': source_vocab_file
    },
    'target_dataset': {
        "files": './data/toy_copy/test/targets.txt',
        'vocab_file': target_vocab_file
    }
}

# %%
# All of our data sets consist of paired texts -- please specify the correct
# Texar data class in the next three lines:

train_data = tx.data.PairedTextData(hparams=train_hparams)
val_data = tx.data.PairedTextData(hparams=val_hparams)
test_data = tx.data.PairedTextData(hparams=test_hparams)

# Texar's data iterators are thin wrappers around the Tensorflow Dataset API
# Please put Texar's data iterator here which can switch between train, test and validation data
iterator = tx.data.TrainTestDataIterator(train=train_data, val=val_data, test=test_data)
batch = iterator.get_next()
train_op, infer_outputs = build_mle_model(batch, train_data) # build the model, get train and inference outputs
# Out:
# WARNING: Entity <function PairedTextData._process_dataset.<locals>.<lambda> at 0x7f3441336730> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Str'
# WARNING: Entity <function PairedTextData._process_dataset.<locals>.<lambda> at 0x7f3440aae1e0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Str'
# WARNING: Entity <function PairedTextData._process_dataset.<locals>.<lambda> at 0x7f3440a6e7b8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Str'

# %% [markdown]
# ## MLE training

# %%
# Now we manually write the training loops...
# not as cosy as Keras, for sure..
# Nothing to do in this cell, just observe

def mle_train_epoch(sess, iterator, train_op):
    """Train the Seq2Seq model for an epoch.
    sess is a TF session to use, 
    iterator is a TrainTestDataIterator with the data,
    train_op is training op in the model's graph.
    """
    iterator.switch_to_train_data(sess)
    for step in range(steps_per_train_epochs):
        try:
            loss = sess.run(train_op) # Run graph until the train op
            if step % display == 0:
                print("step={}, loss={:.4f}".format(step, loss))
        except tf.errors.OutOfRangeError:
            break


def eval_epoch(sess, mode, iterator, batch):
    """ Evaluate an epoch. Mode is 'test' or 'val'.
    """
    if mode == 'val':
        iterator.switch_to_val_data(sess)
    else:
        iterator.switch_to_test_data(sess)

    refs, hypos = [], []
    while True:
        try:
            # fetches are what we want to get back from the session
            # in this case the target texts and the predicted texts
            fetches = [
                batch['target_text'][:, 1:],
                infer_outputs.predicted_ids[:, :, 0]
            ]
            feed_dict = {
                tx.global_mode(): tf.estimator.ModeKeys.PREDICT,
            }
            target_texts, output_ids = \
                sess.run(fetches, feed_dict=feed_dict)

            target_texts = tx.utils.strip_special_tokens(target_texts)
            output_texts = tx.utils.map_ids_to_strs(
                ids=output_ids, vocab=val_data.target_vocab)

            for hypo, ref in zip(output_texts, target_texts):
                hypos.append(hypo)
                refs.append([ref])
        except tf.errors.OutOfRangeError:
            break
    # For evaluation we want to use a BLEU variant:
    # please put here Texar's "moses" corpus BLEU variant.
    return tx.evals.corpus_bleu_moses(list_of_references=refs,
                                        hypotheses=hypos)


def mle_train_and_eval(sess, iterator, batch, train_op):
    """Train the model with MLE and eval.
    """
    best_val_bleu = -1.
    for i in range(mle_training_num_epochs):
        mle_train_epoch(sess, iterator, train_op)

        val_bleu = eval_epoch(sess, 'val', iterator, batch)
        best_val_bleu = max(best_val_bleu, val_bleu)
        print('val epoch={}, BLEU={:.4f}; best-ever={:.4f}'.format(
            i, val_bleu, best_val_bleu))

        test_bleu = eval_epoch(sess, 'test', iterator, batch)
        print('test epoch={}, BLEU={:.4f}'.format(i, test_bleu))

        print('=' * 50)


# The only thing left is to run the training and evaluation:
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(tf.local_variables_initializer())
    sess.run(tf.tables_initializer())
    mle_train_and_eval(sess, iterator, batch, train_op)
# Out:
# step=0, loss=35.0892
# step=50, loss=20.4867
# step=100, loss=3.4471
# step=150, loss=1.5748
# step=200, loss=0.2229
# step=250, loss=0.4378
# step=300, loss=0.3639
# val epoch=0, BLEU=99.6900; best-ever=99.6900
# test epoch=0, BLEU=99.5300
# ==================================================
# step=0, loss=0.2254
# step=50, loss=0.1017
# step=100, loss=0.0435
# step=150, loss=0.1019
# step=200, loss=0.0151
# step=250, loss=0.0152
# step=300, loss=0.0265
# val epoch=1, BLEU=99.8400; best-ever=99.8400
# test epoch=1, BLEU=99.7800
# ==================================================
# step=0, loss=0.0986
# step=50, loss=0.0167
# step=100, loss=0.3825
# step=150, loss=0.2705
# step=200, loss=0.1358
# step=250, loss=0.0312
# step=300, loss=0.1443
# val epoch=2, BLEU=99.9000; best-ever=99.9000
# test epoch=2, BLEU=99.9100
# ==================================================
# step=0, loss=0.1435
# step=50, loss=0.0275
# step=100, loss=0.0193
# step=150, loss=0.0871
# step=200, loss=0.0099
# step=250, loss=0.0090
# step=300, loss=0.0876
# val epoch=3, BLEU=99.2200; best-ever=99.9000
# test epoch=3, BLEU=99.7800
# ==================================================
# step=0, loss=0.1112
# step=50, loss=0.0089
# step=100, loss=0.0792
# step=150, loss=0.0104
# step=200, loss=0.0090
# step=250, loss=0.0107
# step=300, loss=0.0086
# val epoch=4, BLEU=99.9800; best-ever=99.9800
# test epoch=4, BLEU=99.9600
# ==================================================
# step=0, loss=0.0062
# step=50, loss=0.0046
# step=100, loss=0.0040
# step=150, loss=0.0037
# step=200, loss=0.0058
# step=250, loss=0.0279
# step=300, loss=0.2935
# val epoch=5, BLEU=46.6800; best-ever=99.9800
# test epoch=5, BLEU=45.7900
# ==================================================
# step=0, loss=28.2453
# step=50, loss=6.9231
# step=100, loss=0.6307
# step=150, loss=0.2789
# step=200, loss=0.1456
# step=250, loss=0.0716
# step=300, loss=0.1376
# val epoch=6, BLEU=99.5700; best-ever=99.9800
# test epoch=6, BLEU=99.2100
# ==================================================
# step=0, loss=0.0626
# step=50, loss=0.0384
# step=100, loss=0.0477
# step=150, loss=0.0510
# step=200, loss=0.0457
# step=250, loss=0.0348
# step=300, loss=0.0227
# val epoch=7, BLEU=99.7100; best-ever=99.9800
# test epoch=7, BLEU=99.8400
# ==================================================
# step=0, loss=0.1993
# step=50, loss=0.0218
# step=100, loss=0.0186
# step=150, loss=0.0174
# step=200, loss=0.0134
# step=250, loss=0.0129
# step=300, loss=0.0159
# val epoch=8, BLEU=99.8000; best-ever=99.9800
# test epoch=8, BLEU=99.8300
# ==================================================
# step=0, loss=0.0090
# step=50, loss=0.0101
# step=100, loss=0.0087
# step=150, loss=0.0085
# step=200, loss=0.0098
# step=250, loss=0.0094
# step=300, loss=0.0092
# val epoch=9, BLEU=99.4100; best-ever=99.9800
# test epoch=9, BLEU=99.8400
# ==================================================
# step=0, loss=0.0107
# step=50, loss=1.7908
# step=100, loss=0.1311
# step=150, loss=0.1468
# step=200, loss=0.0422
# step=250, loss=0.0588
# step=300, loss=0.0259
# val epoch=10, BLEU=99.6000; best-ever=99.9800
# test epoch=10, BLEU=98.7800
# ==================================================
# step=0, loss=0.0237
# step=50, loss=0.0228
# step=100, loss=0.0185
# step=150, loss=0.0428
# step=200, loss=0.0127
# step=250, loss=0.0182
# step=300, loss=0.0121
# val epoch=11, BLEU=99.0100; best-ever=99.9800
# test epoch=11, BLEU=99.2300
# ==================================================
# step=0, loss=0.0086
# step=50, loss=0.0108
# step=100, loss=0.0084
# step=150, loss=0.0082
# step=200, loss=0.0072
# step=250, loss=0.0061
# step=300, loss=0.0063
# val epoch=12, BLEU=98.5100; best-ever=99.9800
# test epoch=12, BLEU=99.3400
# ==================================================
# step=0, loss=0.0066
# step=50, loss=0.0047
# step=100, loss=0.0048
# step=150, loss=0.0054
# step=200, loss=0.0042
# step=250, loss=0.0043
# step=300, loss=0.0037
# val epoch=13, BLEU=98.5400; best-ever=99.9800
# test epoch=13, BLEU=99.3900
# ==================================================
# step=0, loss=0.0043
# step=50, loss=0.0034
# step=100, loss=0.0033
# step=150, loss=0.0033
# step=200, loss=0.0031
# step=250, loss=0.0030
# step=300, loss=0.0029
# val epoch=14, BLEU=99.0600; best-ever=99.9800
# test epoch=14, BLEU=99.8800
# ==================================================
# step=0, loss=0.0031
# step=50, loss=0.0027
# step=100, loss=0.0023
# step=150, loss=0.0027
# step=200, loss=0.0024
# step=250, loss=0.0027
# step=300, loss=0.0023
# val epoch=15, BLEU=99.0400; best-ever=99.9800
# test epoch=15, BLEU=99.8500
# ==================================================
# step=0, loss=0.0024
# step=50, loss=0.0020
# step=100, loss=0.0021
# step=150, loss=0.0016
# step=200, loss=0.0020
# step=250, loss=0.0017
# step=300, loss=0.0013
# val epoch=16, BLEU=99.0400; best-ever=99.9800
# test epoch=16, BLEU=99.8500
# ==================================================
# step=0, loss=0.0016
# step=50, loss=0.0013
# step=100, loss=0.0016
# step=150, loss=0.0015
# step=200, loss=0.0013
# step=250, loss=0.0012
# step=300, loss=0.0012
# val epoch=17, BLEU=98.5500; best-ever=99.9800
# test epoch=17, BLEU=99.8500
# ==================================================
# step=0, loss=0.0012
# step=50, loss=0.0014
# step=100, loss=0.0012
# step=150, loss=0.0014
# step=200, loss=0.0011
# step=250, loss=0.0010
# step=300, loss=0.0012
# val epoch=18, BLEU=99.0800; best-ever=99.9800
# test epoch=18, BLEU=99.8500
# ==================================================
# step=0, loss=0.0009
# step=50, loss=0.0009
# step=100, loss=0.0009
# step=150, loss=0.0009
# step=200, loss=0.0009
# step=250, loss=0.0008
# step=300, loss=0.0009
# val epoch=19, BLEU=98.5800; best-ever=99.9800
# test epoch=19, BLEU=99.8500
# ==================================================
# step=0, loss=0.0008
# step=50, loss=0.0008
# step=100, loss=0.0009
# step=150, loss=1.0129
# step=200, loss=0.8502
# step=250, loss=0.6674
# step=300, loss=1.0779
# val epoch=20, BLEU=87.2300; best-ever=99.9800
# test epoch=20, BLEU=88.6200
# ==================================================
# step=0, loss=2.6766
# step=50, loss=0.1083
# step=100, loss=0.1011
# step=150, loss=0.2851
# step=200, loss=0.0226
# step=250, loss=0.0189
# step=300, loss=0.0174
# val epoch=21, BLEU=99.7600; best-ever=99.9800
# test epoch=21, BLEU=99.3200
# ==================================================
# step=0, loss=0.0146
# step=50, loss=0.0122
# step=100, loss=0.1001
# step=150, loss=0.0111
# step=200, loss=0.0091
# step=250, loss=0.0082
# step=300, loss=0.0066
# val epoch=22, BLEU=99.7900; best-ever=99.9800
# test epoch=22, BLEU=99.7600
# ==================================================
# step=0, loss=0.0074
# step=50, loss=0.0144
# step=100, loss=0.0061
# step=150, loss=0.0052
# step=200, loss=0.0053
# step=250, loss=0.0045
# step=300, loss=0.0037
# val epoch=23, BLEU=99.8500; best-ever=99.9800
# test epoch=23, BLEU=99.8100
# ==================================================
# step=0, loss=0.0047
# step=50, loss=0.0037
# step=100, loss=0.0035
# step=150, loss=0.0031
# step=200, loss=0.0025
# step=250, loss=0.0029
# step=300, loss=0.0025
# val epoch=24, BLEU=99.8100; best-ever=99.9800
# test epoch=24, BLEU=99.7800
# ==================================================
# step=0, loss=0.0025
# step=50, loss=0.0510
# step=100, loss=0.0026
# step=150, loss=0.1684
# step=200, loss=1.5149
# step=250, loss=0.0116
# step=300, loss=0.2997
# val epoch=25, BLEU=99.3700; best-ever=99.9800
# test epoch=25, BLEU=99.3600
# ==================================================
# step=0, loss=0.3095
# step=50, loss=0.0094
# step=100, loss=24.1196
# step=150, loss=10.0390
# step=200, loss=1.0581
# step=250, loss=2.0699
# step=300, loss=0.3916
# val epoch=26, BLEU=95.0300; best-ever=99.9800
# test epoch=26, BLEU=95.7900
# ==================================================
# step=0, loss=0.3069
# step=50, loss=0.1844
# step=100, loss=0.1863
# step=150, loss=0.3512
# step=200, loss=0.1173
# step=250, loss=0.0476
# step=300, loss=0.0658
# val epoch=27, BLEU=99.4800; best-ever=99.9800
# test epoch=27, BLEU=99.6100
# ==================================================
# step=0, loss=0.0498
# step=50, loss=0.0821
# step=100, loss=0.0625
# step=150, loss=0.2344
# step=200, loss=0.0271
# step=250, loss=0.0268
# step=300, loss=0.0500
# val epoch=28, BLEU=99.3000; best-ever=99.9800
# test epoch=28, BLEU=99.8100
# ==================================================
# step=0, loss=0.0171
# step=50, loss=0.0804
# step=100, loss=0.0221
# step=150, loss=0.0185
# step=200, loss=0.0144
# step=250, loss=0.0174
# step=300, loss=0.0152
# val epoch=29, BLEU=99.3100; best-ever=99.9800
# test epoch=29, BLEU=99.2500
# ==================================================
# step=0, loss=0.0321
# step=50, loss=0.2162
# step=100, loss=0.2758
# step=150, loss=0.0265
# step=200, loss=0.0179
# step=250, loss=0.0175
# step=300, loss=0.0140
# val epoch=30, BLEU=99.3400; best-ever=99.9800
# test epoch=30, BLEU=99.3600
# ==================================================
# step=0, loss=0.0168
# step=50, loss=0.0105
# step=100, loss=0.2028
# step=150, loss=0.0107
# step=200, loss=0.0112
# step=250, loss=0.0429
# step=300, loss=0.0093
# val epoch=31, BLEU=98.5700; best-ever=99.9800
# test epoch=31, BLEU=97.9600
# ==================================================
# step=0, loss=0.0107
# step=50, loss=0.0099
# step=100, loss=0.0092
# step=150, loss=0.0095
# step=200, loss=0.0136
# step=250, loss=0.0069
# step=300, loss=0.0085
# val epoch=32, BLEU=98.7400; best-ever=99.9800
# test epoch=32, BLEU=99.9300
# ==================================================
# step=0, loss=0.0086
# step=50, loss=0.0057
# step=100, loss=0.0057
# step=150, loss=0.0071
# step=200, loss=0.0157
# step=250, loss=0.0571
# step=300, loss=0.0059
# val epoch=33, BLEU=98.7500; best-ever=99.9800
# test epoch=33, BLEU=98.8100
# ==================================================
# step=0, loss=0.0070
# step=50, loss=0.0059
# step=100, loss=0.0074
# step=150, loss=0.0074
# step=200, loss=0.0588
# step=250, loss=0.0061
# step=300, loss=0.0074
# val epoch=34, BLEU=99.3000; best-ever=99.9800
# test epoch=34, BLEU=99.8600
# ==================================================
# step=0, loss=0.0101
# step=50, loss=0.0571
# step=100, loss=0.0734
# step=150, loss=1.4058
# step=200, loss=0.0597
# step=250, loss=0.5635
# step=300, loss=0.0281
# val epoch=35, BLEU=99.6600; best-ever=99.9800
# test epoch=35, BLEU=99.1800
# ==================================================
# step=0, loss=0.0272
# step=50, loss=0.0238
# step=100, loss=0.1772
# step=150, loss=0.0144
# step=200, loss=0.0125
# step=250, loss=0.0098
# step=300, loss=0.0089
# val epoch=36, BLEU=99.9200; best-ever=99.9800
# test epoch=36, BLEU=99.7400
# ==================================================
# step=0, loss=0.0079
# step=50, loss=0.0077
# step=100, loss=0.0063
# step=150, loss=0.0054
# step=200, loss=0.0043
# step=250, loss=0.0053
# step=300, loss=0.0047
# val epoch=37, BLEU=99.9500; best-ever=99.9800
# test epoch=37, BLEU=99.9100
# ==================================================
# step=0, loss=0.0039
# step=50, loss=0.0034
# step=100, loss=0.0032
# step=150, loss=0.0033
# step=200, loss=0.0028
# step=250, loss=0.0025
# step=300, loss=0.0026
# val epoch=38, BLEU=99.9500; best-ever=99.9800
# test epoch=38, BLEU=99.9200
# ==================================================
# step=0, loss=0.0023
# step=50, loss=0.0024
# step=100, loss=0.0022
# step=150, loss=0.0019
# step=200, loss=0.0023
# step=250, loss=0.0021
# step=300, loss=0.0022
# val epoch=39, BLEU=99.9400; best-ever=99.9800
# test epoch=39, BLEU=99.9200
# ==================================================

# %% [markdown]
# # Attention Seq2Seq with Policy gradient

# %% [markdown]
# ## Building the model

# %%
def build_rl_model(batch, train_data):
    """Build a seq2seq model trained with Policy Gradient.
    """
    
    # Our RL-trained model will be almost totally the same as the previous one,
    # except that we add sampled outputs for Policy Gradient.
    # So, please repeat here the missing elements of the previous model. (Copy & paste...)
    
    source_embedder = tx.modules.WordEmbedder(
        vocab_size=train_data.source_vocab.size, hparams=embedder_hparams)
    
    encoder = tx.modules.BidirectionalRNNEncoder(hparams=encoder_hparams)
    
    enc_outputs, _ = encoder(source_embedder(batch['source_text_ids']))

    target_embedder = tx.modules.WordEmbedder(
        vocab_size=train_data.target_vocab.size, hparams=embedder_hparams)

    decoder = tx.modules.AttentionRNNDecoder(
        memory=tf.concat(enc_outputs, axis=2),
        memory_sequence_length=batch['source_length'],
        vocab_size=train_data.target_vocab.size,
        hparams=decoder_hparams)

    # MLE pretraining

    mle_training_outputs, _, _ = decoder(
        decoding_strategy='train_greedy', # Please specify greedy training decoding here 
                                          # see the possible values in the Texar "Decoders" documentation section
        inputs=target_embedder(batch['target_text_ids'][:, :-1]),
        sequence_length=batch['target_length'] - 1)
    
    mle_loss = tx.losses.sequence_sparse_softmax_cross_entropy(
        labels=batch['target_text_ids'][:, 1:],
        logits=mle_training_outputs.logits,
        sequence_length=batch['target_length'] - 1)

    mle_train_op = tx.core.get_train_op(mle_loss)

    start_tokens = tf.ones_like(batch['target_length']) * train_data.target_vocab.bos_token_id

    beam_search_outputs, _, _ = \
        tx.modules.beam_search_decode(
            decoder_or_cell=decoder,
            embedding=target_embedder,
            start_tokens=start_tokens,
            end_token=train_data.target_vocab.eos_token_id,
            beam_width=beam_width,
            max_decoding_length=60)    
    
    # Here comes the novelty...
    # We need random sampling for Policy Gradient
    sampled_outputs, _, sequence_length = decoder(
        decoding_strategy= 'infer_sample', # Please add here the correct 'decoding strategy' for random sampling
        start_tokens=start_tokens,
        end_token=train_data.target_vocab.eos_token_id,
        embedding=target_embedder,
        max_decoding_length=30)

    # We need to return a bit more things from the graph for Policy Gradient
    return sampled_outputs, mle_train_op, sequence_length, beam_search_outputs

# %% [markdown]
# ## Data sets and iterator

# %%
tf.reset_default_graph()

# Please repeat here the previous definitions for our data sets and iterator!


train_data = tx.data.PairedTextData(hparams=train_hparams)
val_data = tx.data.PairedTextData(hparams=val_hparams)
test_data = tx.data.PairedTextData(hparams=test_hparams)

iterator = tx.data.TrainTestDataIterator(train=train_data, val=val_data, test=test_data)

batch = iterator.get_next()

# We build the model:
sampled_outputs, mle_train_op, sequence_length, infer_outputs = build_rl_model(batch, train_data)
# Out:
# WARNING: Entity <function PairedTextData._process_dataset.<locals>.<lambda> at 0x7f3347d39d08> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Str'
# WARNING: Entity <function PairedTextData._process_dataset.<locals>.<lambda> at 0x7f3347cc21e0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Str'
# WARNING: Entity <function PairedTextData._process_dataset.<locals>.<lambda> at 0x7f33cbfd9620> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Str'

# %% [markdown]
# ## Agent definition

# %%
# Now a crucial point: we need te create a Texar Sequence Policy Gradient Agent
# Please specify the correct Texar class!
agent = tx.agents.SeqPGAgent(
    samples=sampled_outputs.sample_id,
    logits=sampled_outputs.logits,
    sequence_length=sequence_length,
    hparams={'discount_factor': 0.95, 'entropy_weight': 0.5})

# %% [markdown]
# ## Policy gradient training

# %%
# PG training and evaluation function
def pg_train_and_eval_epoch(sess, agent, iterator, batch):
    best_val_bleu = -1.
    for step in range(steps_per_train_epochs):
        iterator.switch_to_train_data(sess)

        
        extra_fetches = {
            'truth': batch['target_text_ids'],
        }

        # The agent needs to get the samples with the current policy.
        # Please add the the correct agent method in the next line!!
        # to be clear: you will need something like 
        # fetches = agent.<METHOD_NAME>(extra_fetches=extra_fetches) 
        # here.
        fetches = agent.get_samples(extra_fetches=extra_fetches)

        sample_text = tx.utils.map_ids_to_strs(
            fetches['samples'], train_data.target_vocab,
            strip_eos=False, join=False)
        truth_text = tx.utils.map_ids_to_strs(
            fetches['truth'], train_data.target_vocab,
            strip_eos=False, join=False)    

        # Compute the rewards
        reward = []
        for ref, hyp in zip(truth_text, sample_text):
            r = tx.evals.sentence_bleu([ref], hyp, smooth=True)
            reward.append(r)

        # Now we need to do the actual weight updates with the policy gradient,
        # in the Texar API this is called "observing".
        # Please add, again, the correct method name in the next line!
        loss = agent.observe(reward=reward)

        # Displays & evaluates
        if step == 1 or step % display == 0:
            print("step={}, loss={:.4f}, reward={:.4f}".format(
                step, loss, np.mean(reward)))

        if step % display == 0:
            val_bleu = eval_epoch(sess, 'val', iterator, batch)
            best_val_bleu = max(best_val_bleu, val_bleu)
            print('val step={}, BLEU={:.4f}; best-ever={:.4f}'.format(
                step, val_bleu, best_val_bleu))

            test_bleu = eval_epoch(sess, 'test', iterator, batch)
            print('test step={}, BLEU={:.4f}'.format(step, test_bleu))
            print('=' * 50)

# %% [markdown]
# ## Running it

# %%
mle_training_num_epochs = 30 # Specify the number of MLE training epochs!
pg_train_num_epochs = 10 # Specify the number of PG training epochs!

# Now we can run the training and see how the (untuned) Policy Gradient training quickly ruins 
# the MLE results...
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(tf.local_variables_initializer())
    sess.run(tf.tables_initializer())

    print("== Starting MLE pretraining ==")

    mle_train_and_eval(sess, iterator, batch, mle_train_op)

    print("== Starting PG training ==")

    agent.sess = sess

    for epoch in range(pg_train_num_epochs):
        print('=' * 50)
        print('== EPOCH NO', epoch, '==')
        print('=' * 50)
        pg_train_and_eval_epoch(sess, agent, iterator, batch)
# Out:
# == Starting MLE pretraining ==
# step=0, loss=34.3719
# step=50, loss=22.8897
# step=100, loss=4.1019
# step=150, loss=2.6688
# step=200, loss=0.1360
# step=250, loss=0.0739
# step=300, loss=0.0400
# val epoch=0, BLEU=99.7800; best-ever=99.7800
# test epoch=0, BLEU=99.7500
# ==================================================
# step=0, loss=0.1761
# step=50, loss=0.0508
# step=100, loss=0.1909
# step=150, loss=5.2103
# step=200, loss=0.1124
# step=250, loss=0.0544
# step=300, loss=0.0718
# val epoch=1, BLEU=99.4700; best-ever=99.7800
# test epoch=1, BLEU=99.5000
# ==================================================
# step=0, loss=0.0703
# step=50, loss=0.0323
# step=100, loss=0.0681
# step=150, loss=0.1945
# step=200, loss=0.1329
# step=250, loss=0.1947
# step=300, loss=0.0347
# val epoch=2, BLEU=99.8900; best-ever=99.8900
# test epoch=2, BLEU=99.9400
# ==================================================
# step=0, loss=0.0203
# step=50, loss=0.0137
# step=100, loss=0.0106
# step=150, loss=0.0366
# step=200, loss=0.0207
# step=250, loss=0.0080
# step=300, loss=0.0069
# val epoch=3, BLEU=99.9500; best-ever=99.9500
# test epoch=3, BLEU=99.9800
# ==================================================
# step=0, loss=0.0270
# step=50, loss=0.0110
# step=100, loss=0.0229
# step=150, loss=0.0175
# step=200, loss=0.0193
# step=250, loss=0.0145
# step=300, loss=0.0126
# val epoch=4, BLEU=99.7500; best-ever=99.9500
# test epoch=4, BLEU=99.5700
# ==================================================
# step=0, loss=0.0141
# step=50, loss=0.3344
# step=100, loss=11.0364
# step=150, loss=1.4028
# step=200, loss=0.3767
# step=250, loss=0.3104
# step=300, loss=0.0740
# val epoch=5, BLEU=99.5900; best-ever=99.9500
# test epoch=5, BLEU=99.6200
# ==================================================
# step=0, loss=0.3310
# step=50, loss=0.4811
# step=100, loss=0.0306
# step=150, loss=0.0489
# step=200, loss=0.1033
# step=250, loss=0.0262
# step=300, loss=0.0859
# val epoch=6, BLEU=99.5800; best-ever=99.9500
# test epoch=6, BLEU=99.5600
# ==================================================
# step=0, loss=0.0219
# step=50, loss=0.0233
# step=100, loss=0.6975
# step=150, loss=0.3176
# step=200, loss=0.0149
# step=250, loss=0.0145
# step=300, loss=0.0095
# val epoch=7, BLEU=99.9400; best-ever=99.9500
# test epoch=7, BLEU=99.8700
# ==================================================
# step=0, loss=0.0113
# step=50, loss=0.0095
# step=100, loss=0.0071
# step=150, loss=0.0073
# step=200, loss=0.0218
# step=250, loss=0.0129
# step=300, loss=0.0102
# val epoch=8, BLEU=99.7900; best-ever=99.9500
# test epoch=8, BLEU=99.7200
# ==================================================
# step=0, loss=0.0093
# step=50, loss=0.0104
# step=100, loss=0.0230
# step=150, loss=0.1165
# step=200, loss=0.0313
# step=250, loss=0.0259
# step=300, loss=0.0179
# val epoch=9, BLEU=99.9600; best-ever=99.9600
# test epoch=9, BLEU=99.9400
# ==================================================
# step=0, loss=0.0164
# step=50, loss=0.0133
# step=100, loss=0.0111
# step=150, loss=1.3840
# step=200, loss=0.8348
# step=250, loss=0.1854
# step=300, loss=3.4075
# val epoch=10, BLEU=90.3200; best-ever=99.9600
# test epoch=10, BLEU=88.0200
# ==================================================
# step=0, loss=0.7369
# step=50, loss=0.0627
# step=100, loss=0.0246
# step=150, loss=0.2339
# step=200, loss=1.8235
# step=250, loss=0.0786
# step=300, loss=0.5022
# val epoch=11, BLEU=99.1400; best-ever=99.9600
# test epoch=11, BLEU=99.3100
# ==================================================
# step=0, loss=1.3191
# step=50, loss=0.7978
# step=100, loss=0.0561
# step=150, loss=0.6651
# step=200, loss=0.1970
# step=250, loss=0.0830
# step=300, loss=0.0236
# val epoch=12, BLEU=99.7400; best-ever=99.9600
# test epoch=12, BLEU=99.5400
# ==================================================
# step=0, loss=0.1754
# step=50, loss=0.0518
# step=100, loss=0.1597
# step=150, loss=0.2715
# step=200, loss=0.0122
# step=250, loss=0.0108
# step=300, loss=0.0111
# val epoch=13, BLEU=99.8700; best-ever=99.9600
# test epoch=13, BLEU=99.8700
# ==================================================
# step=0, loss=0.0093
# step=50, loss=0.0071
# step=100, loss=0.0074
# step=150, loss=0.0059
# step=200, loss=0.0045
# step=250, loss=0.0078
# step=300, loss=0.0050
# val epoch=14, BLEU=99.8500; best-ever=99.9600
# test epoch=14, BLEU=99.3500
# ==================================================
# step=0, loss=0.0055
# step=50, loss=0.0062
# step=100, loss=20.1630
# step=150, loss=0.8164
# step=200, loss=0.1675
# step=250, loss=0.1420
# step=300, loss=0.6400
# val epoch=15, BLEU=99.1800; best-ever=99.9600
# test epoch=15, BLEU=99.5400
# ==================================================
# step=0, loss=0.0881
# step=50, loss=0.0449
# step=100, loss=0.0445
# step=150, loss=3.4160
# step=200, loss=0.2916
# step=250, loss=0.0716
# step=300, loss=0.0479
# val epoch=16, BLEU=99.7300; best-ever=99.9600
# test epoch=16, BLEU=99.7200
# ==================================================
# step=0, loss=0.0485
# step=50, loss=0.0397
# step=100, loss=0.0286
# step=150, loss=0.0244
# step=200, loss=0.0235
# step=250, loss=0.0347
# step=300, loss=0.1813
# val epoch=17, BLEU=97.8800; best-ever=99.9600
# test epoch=17, BLEU=96.3500
# ==================================================
# step=0, loss=0.2448
# step=50, loss=2.3884
# step=100, loss=0.4103
# step=150, loss=0.7308
# step=200, loss=1.1762
# step=250, loss=0.2406
# step=300, loss=0.2997
# val epoch=18, BLEU=97.3900; best-ever=99.9600
# test epoch=18, BLEU=98.8800
# ==================================================
# step=0, loss=0.1418
# step=50, loss=0.4105
# step=100, loss=0.1609
# step=150, loss=0.4276
# step=200, loss=0.3300
# step=250, loss=0.0772
# step=300, loss=0.8238
# val epoch=19, BLEU=99.2000; best-ever=99.9600
# test epoch=19, BLEU=99.0500
# ==================================================
# step=0, loss=0.6477
# step=50, loss=0.0588
# step=100, loss=0.1357
# step=150, loss=0.0337
# step=200, loss=0.0328
# step=250, loss=0.0319
# step=300, loss=0.0290
# val epoch=20, BLEU=99.9200; best-ever=99.9600
# test epoch=20, BLEU=99.8900
# ==================================================
# step=0, loss=0.0198
# step=50, loss=0.0205
# step=100, loss=0.0154
# step=150, loss=0.0139
# step=200, loss=0.0134
# step=250, loss=0.0101
# step=300, loss=0.0126
# val epoch=21, BLEU=99.9000; best-ever=99.9600
# test epoch=21, BLEU=99.8400
# ==================================================
# step=0, loss=0.0142
# step=50, loss=0.0130
# step=100, loss=0.0108
# step=150, loss=0.0124
# step=200, loss=0.0089
# step=250, loss=0.0106
# step=300, loss=0.0078
# val epoch=22, BLEU=99.9400; best-ever=99.9600
# test epoch=22, BLEU=99.9300
# ==================================================
# step=0, loss=0.0076
# step=50, loss=0.0074
# step=100, loss=0.0056
# step=150, loss=0.0056
# step=200, loss=0.0065
# step=250, loss=0.0072
# step=300, loss=0.0058
# val epoch=23, BLEU=99.9700; best-ever=99.9700
# test epoch=23, BLEU=99.8900
# ==================================================
# step=0, loss=0.0438
# step=50, loss=0.0057
# step=100, loss=0.0047
# step=150, loss=0.0055
# step=200, loss=0.0116
# step=250, loss=0.0050
# step=300, loss=0.0035
# val epoch=24, BLEU=99.9400; best-ever=99.9700
# test epoch=24, BLEU=99.9400
# ==================================================
# step=0, loss=0.0050
# step=50, loss=47.8031
# step=100, loss=29.1733
# step=150, loss=29.1724
# step=200, loss=24.6189
# step=250, loss=17.3748
# step=300, loss=6.2428
# val epoch=25, BLEU=74.2300; best-ever=99.9700
# test epoch=25, BLEU=72.9600
# ==================================================
# step=0, loss=4.7477
# step=50, loss=2.1567
# step=100, loss=1.2116
# step=150, loss=1.7358
# step=200, loss=0.2742
# step=250, loss=0.1096
# step=300, loss=0.1229
# val epoch=26, BLEU=96.3700; best-ever=99.9700
# test epoch=26, BLEU=95.6500
# ==================================================
# step=0, loss=0.1505
# step=50, loss=0.2604
# step=100, loss=0.2077
# step=150, loss=0.2979
# step=200, loss=0.0653
# step=250, loss=0.0606
# step=300, loss=0.0421
# val epoch=27, BLEU=99.0900; best-ever=99.9700
# test epoch=27, BLEU=98.5400
# ==================================================
# step=0, loss=0.0489
# step=50, loss=0.0754
# step=100, loss=0.1958
# step=150, loss=0.1318
# step=200, loss=0.0336
# step=250, loss=0.0219
# step=300, loss=0.0183
# val epoch=28, BLEU=99.2200; best-ever=99.9700
# test epoch=28, BLEU=99.1500
# ==================================================
# step=0, loss=0.0259
# step=50, loss=0.0217
# step=100, loss=0.1039
# step=150, loss=0.0144
# step=200, loss=0.0159
# step=250, loss=0.0123
# step=300, loss=0.0203
# val epoch=29, BLEU=99.5200; best-ever=99.9700
# test epoch=29, BLEU=99.2500
# ==================================================
# == Starting PG training ==
# ==================================================
# == EPOCH NO 0 ==
# ==================================================
# step=0, loss=1.6896, reward=66.8347
# val step=0, BLEU=98.9400; best-ever=98.9400
# test step=0, BLEU=98.9200
# ==================================================
# step=1, loss=0.8631, reward=61.1040
# step=50, loss=39.8706, reward=58.9763
# val step=50, BLEU=72.1000; best-ever=98.9400
# test step=50, BLEU=72.8700
# ==================================================
# step=100, loss=32.7066, reward=34.2180
# val step=100, BLEU=62.5300; best-ever=98.9400
# test step=100, BLEU=67.2900
# ==================================================
# step=150, loss=38.7291, reward=46.4995
# val step=150, BLEU=82.6100; best-ever=98.9400
# test step=150, BLEU=82.3300
# ==================================================
# step=200, loss=21.3711, reward=55.4970
# val step=200, BLEU=83.6100; best-ever=98.9400
# test step=200, BLEU=82.5200
# ==================================================
# step=250, loss=13.3025, reward=55.7134
# val step=250, BLEU=79.4700; best-ever=98.9400
# test step=250, BLEU=79.0800
# ==================================================
# step=300, loss=13.3573, reward=32.1480
# val step=300, BLEU=78.8200; best-ever=98.9400
# test step=300, BLEU=76.3800
# ==================================================
# ==================================================
# == EPOCH NO 1 ==
# ==================================================
# step=0, loss=21.2844, reward=26.0734
# val step=0, BLEU=50.1800; best-ever=50.1800
# test step=0, BLEU=51.5400
# ==================================================
# step=1, loss=33.0932, reward=29.8742
# step=50, loss=46.8504, reward=4.8939
# val step=50, BLEU=0.0000; best-ever=50.1800
# test step=50, BLEU=0.0800
# ==================================================
# step=100, loss=49.1482, reward=4.7330
# val step=100, BLEU=0.0000; best-ever=50.1800
# test step=100, BLEU=0.0000
# ==================================================
# step=150, loss=44.9760, reward=4.5376
# val step=150, BLEU=0.0000; best-ever=50.1800
# test step=150, BLEU=0.0000
# ==================================================
# step=200, loss=53.4474, reward=4.9865
# val step=200, BLEU=0.0700; best-ever=50.1800
# test step=200, BLEU=0.0000
# ==================================================
# step=250, loss=61.9078, reward=4.7850
# val step=250, BLEU=0.0700; best-ever=50.1800
# test step=250, BLEU=0.0000
# ==================================================
# step=300, loss=67.6691, reward=4.7960
# val step=300, BLEU=0.0600; best-ever=50.1800
# test step=300, BLEU=0.0000
# ==================================================
# ==================================================
# == EPOCH NO 2 ==
# ==================================================
# step=0, loss=66.9140, reward=4.9689
# val step=0, BLEU=0.0700; best-ever=0.0700
# test step=0, BLEU=0.1000
# ==================================================
# step=1, loss=71.4009, reward=4.9889
# step=50, loss=77.8425, reward=4.9072
# val step=50, BLEU=0.0000; best-ever=0.0700
# test step=50, BLEU=0.0000
# ==================================================
# step=100, loss=74.5054, reward=4.9493
# val step=100, BLEU=0.0000; best-ever=0.0700
# test step=100, BLEU=0.0600
# ==================================================
# step=150, loss=116.0139, reward=5.6425
# val step=150, BLEU=0.1000; best-ever=0.1000
# test step=150, BLEU=0.0900
# ==================================================
# step=200, loss=94.4602, reward=5.3860
# val step=200, BLEU=0.0900; best-ever=0.1000
# test step=200, BLEU=0.0900
# ==================================================
# step=250, loss=0.6266, reward=2.3683
# val step=250, BLEU=0.0000; best-ever=0.1000
# test step=250, BLEU=0.0000
# ==================================================
# step=300, loss=0.0536, reward=2.1121
# val step=300, BLEU=0.0000; best-ever=0.1000
# test step=300, BLEU=0.0000
# ==================================================
# ==================================================
# == EPOCH NO 3 ==
# ==================================================
# step=0, loss=5.0022, reward=8.1207
# val step=0, BLEU=0.0000; best-ever=0.0000
# test step=0, BLEU=0.0000
# ==================================================
# step=1, loss=6.6643, reward=13.4039
# step=50, loss=7.9600, reward=8.0123
# val step=50, BLEU=0.0000; best-ever=0.0000
# test step=50, BLEU=0.0000
# ==================================================
# step=100, loss=4.0396, reward=5.8350
# val step=100, BLEU=0.0000; best-ever=0.0000
# test step=100, BLEU=0.0000
# ==================================================
# step=150, loss=0.9297, reward=2.0330
# val step=150, BLEU=0.0000; best-ever=0.0000
# test step=150, BLEU=0.0000
# ==================================================
# step=200, loss=11.5452, reward=11.2841
# val step=200, BLEU=0.0000; best-ever=0.0000
# test step=200, BLEU=0.0000
# ==================================================
# step=250, loss=4.0869, reward=5.3960
# val step=250, BLEU=0.0000; best-ever=0.0000
# test step=250, BLEU=0.0000
# ==================================================
# step=300, loss=7.0685, reward=7.7971
# val step=300, BLEU=0.0000; best-ever=0.0000
# test step=300, BLEU=0.0000
# ==================================================
# ==================================================
# == EPOCH NO 4 ==
# ==================================================
# step=0, loss=7.1412, reward=7.2364
# val step=0, BLEU=0.0000; best-ever=0.0000
# test step=0, BLEU=0.0000
# ==================================================
# step=1, loss=9.4428, reward=9.8891
# step=50, loss=7.1774, reward=6.4457
# val step=50, BLEU=0.0000; best-ever=0.0000
# test step=50, BLEU=0.0000
# ==================================================
# step=100, loss=7.0701, reward=6.8424
# val step=100, BLEU=0.0000; best-ever=0.0000
# test step=100, BLEU=0.0000
# ==================================================
# step=150, loss=3.3839, reward=8.1936
# val step=150, BLEU=0.0000; best-ever=0.0000
# test step=150, BLEU=0.0000
# ==================================================
# step=200, loss=7.6544, reward=6.7898
# val step=200, BLEU=0.0000; best-ever=0.0000
# test step=200, BLEU=0.0000
# ==================================================
# step=250, loss=4.3258, reward=7.1465
# val step=250, BLEU=0.0000; best-ever=0.0000
# test step=250, BLEU=0.0000
# ==================================================
# step=300, loss=17.3672, reward=10.9708
# val step=300, BLEU=0.0000; best-ever=0.0000
# test step=300, BLEU=0.0000
# ==================================================
# ==================================================
# == EPOCH NO 5 ==
# ==================================================
# step=0, loss=9.1822, reward=9.0708
# val step=0, BLEU=0.0000; best-ever=0.0000
# test step=0, BLEU=0.0000
# ==================================================
# step=1, loss=8.7413, reward=8.1973
# step=50, loss=4.3387, reward=6.0582
# val step=50, BLEU=0.0000; best-ever=0.0000
# test step=50, BLEU=0.0000
# ==================================================
# step=100, loss=8.3544, reward=10.2617
# val step=100, BLEU=0.0000; best-ever=0.0000
# test step=100, BLEU=0.0000
# ==================================================
# step=150, loss=3.5076, reward=6.7448
# val step=150, BLEU=0.0000; best-ever=0.0000
# test step=150, BLEU=0.0000
# ==================================================
# step=200, loss=5.9263, reward=9.6812
# val step=200, BLEU=0.0000; best-ever=0.0000
# test step=200, BLEU=0.0000
# ==================================================
# step=250, loss=6.5673, reward=4.5302
# val step=250, BLEU=0.0000; best-ever=0.0000
# test step=250, BLEU=0.0000
# ==================================================
# step=300, loss=0.8935, reward=2.0630
# val step=300, BLEU=0.0000; best-ever=0.0000
# test step=300, BLEU=0.0000
# ==================================================
# ==================================================
# == EPOCH NO 6 ==
# ==================================================
# step=0, loss=1.3176, reward=2.6720
# val step=0, BLEU=0.0000; best-ever=0.0000
# test step=0, BLEU=0.0000
# ==================================================
# step=1, loss=0.8421, reward=3.6609
# step=50, loss=2.8107, reward=6.5505
# val step=50, BLEU=0.0000; best-ever=0.0000
# test step=50, BLEU=0.0000
# ==================================================
# step=100, loss=6.8452, reward=7.0373
# val step=100, BLEU=0.0000; best-ever=0.0000
# test step=100, BLEU=0.0000
# ==================================================
# step=150, loss=10.0009, reward=8.8806
# val step=150, BLEU=0.0000; best-ever=0.0000
# test step=150, BLEU=0.0000
# ==================================================
# step=200, loss=4.1418, reward=6.5468
# val step=200, BLEU=0.0000; best-ever=0.0000
# test step=200, BLEU=0.0000
# ==================================================
# step=250, loss=11.9064, reward=9.3103
# val step=250, BLEU=0.0000; best-ever=0.0000
# test step=250, BLEU=0.0000
# ==================================================
# step=300, loss=2.6908, reward=6.5725
# val step=300, BLEU=0.0000; best-ever=0.0000
# test step=300, BLEU=0.0000
# ==================================================
# ==================================================
# == EPOCH NO 7 ==
# ==================================================
# step=0, loss=2.1590, reward=5.5922
# val step=0, BLEU=0.0000; best-ever=0.0000
# test step=0, BLEU=0.0000
# ==================================================
# step=1, loss=1.6652, reward=5.7559
# step=50, loss=0.4936, reward=1.8260
# val step=50, BLEU=0.0000; best-ever=0.0000
# test step=50, BLEU=0.0000
# ==================================================
# step=100, loss=0.8215, reward=2.5254
# val step=100, BLEU=0.0000; best-ever=0.0000
# test step=100, BLEU=0.0000
# ==================================================
# step=150, loss=8.7239, reward=7.8797
# val step=150, BLEU=0.0000; best-ever=0.0000
# test step=150, BLEU=0.0000
# ==================================================
# step=200, loss=6.3475, reward=11.1338
# val step=200, BLEU=0.0000; best-ever=0.0000
# test step=200, BLEU=0.0000
# ==================================================
# step=250, loss=1.4854, reward=6.4129
# val step=250, BLEU=0.0000; best-ever=0.0000
# test step=250, BLEU=0.0000
# ==================================================
# step=300, loss=3.1024, reward=6.1024
# val step=300, BLEU=0.0000; best-ever=0.0000
# test step=300, BLEU=0.0000
# ==================================================
# ==================================================
# == EPOCH NO 8 ==
# ==================================================
# step=0, loss=4.3857, reward=4.4604
# val step=0, BLEU=0.0000; best-ever=0.0000
# test step=0, BLEU=0.0000
# ==================================================
# step=1, loss=10.1092, reward=11.4021
# step=50, loss=2.8712, reward=6.4604
# val step=50, BLEU=0.0000; best-ever=0.0000
# test step=50, BLEU=0.0000
# ==================================================
# step=100, loss=3.4223, reward=6.0011
# val step=100, BLEU=0.0000; best-ever=0.0000
# test step=100, BLEU=0.0000
# ==================================================
# step=150, loss=2.1843, reward=7.7460
# val step=150, BLEU=0.0000; best-ever=0.0000
# test step=150, BLEU=0.0000
# ==================================================
# step=200, loss=0.9393, reward=8.1984
# val step=200, BLEU=0.0000; best-ever=0.0000
# test step=200, BLEU=0.0000
# ==================================================
# step=250, loss=1.1847, reward=6.3179
# val step=250, BLEU=0.0000; best-ever=0.0000
# test step=250, BLEU=0.0000
# ==================================================
# step=300, loss=4.5423, reward=7.7189
# val step=300, BLEU=0.0000; best-ever=0.0000
# test step=300, BLEU=0.0000
# ==================================================
# ==================================================
# == EPOCH NO 9 ==
# ==================================================
# step=0, loss=6.2294, reward=6.5150
# val step=0, BLEU=0.0000; best-ever=0.0000
# test step=0, BLEU=0.0000
# ==================================================
# step=1, loss=4.1362, reward=7.5490
# step=50, loss=6.8508, reward=7.5903
# val step=50, BLEU=0.0000; best-ever=0.0000
# test step=50, BLEU=0.0000
# ==================================================
# step=100, loss=1.9345, reward=5.8418
# val step=100, BLEU=0.0000; best-ever=0.0000
# test step=100, BLEU=0.0000
# ==================================================
# step=150, loss=1.3708, reward=6.9666
# val step=150, BLEU=0.0000; best-ever=0.0000
# test step=150, BLEU=0.0000
# ==================================================
# step=200, loss=2.4627, reward=7.0034
# val step=200, BLEU=0.0000; best-ever=0.0000
# test step=200, BLEU=0.0000
# ==================================================
# step=250, loss=2.9551, reward=9.0174
# val step=250, BLEU=0.0000; best-ever=0.0000
# test step=250, BLEU=0.0000
# ==================================================
# step=300, loss=7.4353, reward=6.5894
# val step=300, BLEU=0.0000; best-ever=0.0000
# test step=300, BLEU=0.0000
# ==================================================
